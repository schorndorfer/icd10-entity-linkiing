# %%
from neo4j import GraphDatabase
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
USER = os.getenv('NEO4J_USERNAME')
URI = os.getenv('LOCAL_NEO4J_URI')
PASSWORD = os.getenv('LOCAL_NEO4J_PASSWORD')
AUTH = (USER, PASSWORD)

# %%
driver = GraphDatabase.driver(URI, auth=AUTH)

try:
    driver.verify_connectivity()
    print("Connection established successfully.")
except Exception as e:
    print(f"Connection failed: {e}")

driver.close()
# Out:
# Connection established successfully.

# %%
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    records, summary, keys = driver.execute_query(
        """
        MATCH (c:Code)
        RETURN c
        LIMIT 10
        """,
    )

    # Loop through results
    for record in records:
        print(f"Found node: {record}")

    # Print summary information
    print(f"Query completed in {summary.result_available_after} ms.")
# Out:
# Found node: <Record c=<Node element_id='4:c07499e7-d50e-45bf-870a-8fbbfe5db3fc:0' labels=frozenset({'Code'}) properties={'chapter': 1, 'code': 'A00', 'section_id': 'A00-A09', 'level': 0, 'description': 'Cholera', 'is_billable': False}>>
# Found node: <Record c=<Node element_id='4:c07499e7-d50e-45bf-870a-8fbbfe5db3fc:1' labels=frozenset({'Code'}) properties={'chapter': 1, 'code': 'A00.0', 'section_id': 'A00-A09', 'level': 1, 'description': 'Cholera due to Vibrio cholerae 01, biovar cholerae', 'is_billable': True}>>
# Found node: <Record c=<Node element_id='4:c07499e7-d50e-45bf-870a-8fbbfe5db3fc:2' labels=frozenset({'Code'}) properties={'chapter': 1, 'code': 'A00.1', 'section_id': 'A00-A09', 'level': 1, 'description': 'Cholera due to Vibrio cholerae 01, biovar eltor', 'is_billable': True}>>
# Found node: <Record c=<Node element_id='4:c07499e7-d50e-45bf-870a-8fbbfe5db3fc:3' labels=frozenset({'Code'}) properties={'chapter': 1, 'code': 'A00.9', 'section_id': 'A00-A09', 'level': 1, 'description': 'Cholera, unspecified', 'is_billable': True}>>
# Found node: <Record c=<Node element_id='4:c07499e7-d50e-45bf-870a-8fbbfe5db3fc:4' labels=frozenset({'Code'}) properties={'chapter': 1, 'code': 'A01', 'section_id': 'A00-A09', 'level': 0, 'description': 'Typhoid and paratyphoid fevers', 'is_billable': False}>>
# Found node: <Record c=<Node element_id='4:c07499e7-d50e-45bf-870a-8fbbfe5db3fc:5' labels=frozenset({'Code'}) properties={'chapter': 1, 'code': 'A01.0', 'section_id': 'A00-A09', 'level': 1, 'description': 'Typhoid fever', 'is_billable': False}>>
# Found node: <Record c=<Node element_id='4:c07499e7-d50e-45bf-870a-8fbbfe5db3fc:6' labels=frozenset({'Code'}) properties={'chapter': 1, 'code': 'A01.00', 'section_id': 'A00-A09', 'level': 2, 'description': 'Typhoid fever, unspecified', 'is_billable': True}>>
# Found node: <Record c=<Node element_id='4:c07499e7-d50e-45bf-870a-8fbbfe5db3fc:7' labels=frozenset({'Code'}) properties={'chapter': 1, 'code': 'A01.01', 'section_id': 'A00-A09', 'level': 2, 'description': 'Typhoid meningitis', 'is_billable': True}>>
# Found node: <Record c=<Node element_id='4:c07499e7-d50e-45bf-870a-8fbbfe5db3fc:8' labels=frozenset({'Code'}) properties={'chapter': 1, 'code': 'A01.02', 'section_id': 'A00-A09', 'level': 2, 'description': 'Typhoid fever with heart involvement', 'is_billable': True}>>
# Found node: <Record c=<Node element_id='4:c07499e7-d50e-45bf-870a-8fbbfe5db3fc:9' labels=frozenset({'Code'}) properties={'chapter': 1, 'code': 'A01.03', 'section_id': 'A00-A09', 'level': 2, 'description': 'Typhoid pneumonia', 'is_billable': True}>>
# Query completed in 2 ms.
